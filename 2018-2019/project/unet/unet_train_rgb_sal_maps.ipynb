# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os

from keras.callbacks import ModelCheckpoint
from unet import unet
from utils.dataset_utils import load_dataset_split, load_images_from_list
from utils.input_output import read_json, write_json
from utils.vis_utils import plot_image_mask_prediction, plot_train_val
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1.1 Change parameters of the experiment (and hyperparameters from ../config.py)

# %%
UNET_NAME = config.UNET_NAME
EXPERIMENT_NAME = config.EXPERIMENT_NAME
DATASET_PATH = f'../datasets/{config.DATASET_NAME}'

# %%
CHECKPOINTS_PATH = f'../checkpoints'
CHECKPOINT_FILENAME = f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}/{UNET_NAME}.hdf5'
LOGS_PATH = f'../logs'
LOGS_FILENAME = f'{LOGS_PATH}/{EXPERIMENT_NAME}.json'
RESULTS_PATH = f'../results/{EXPERIMENT_NAME}'

# %%
# !rm -rf $f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}'
os.makedirs(f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}')

# %%
a = np.ones([2,5,5,3])
b = np.zeros([2,5,5,1])
print(np.concatenate([a, b], axis=-1).shape)
# Out:
# (2, 5, 5, 4)

# %% [markdown]
# ## 2. Load the dataset splits

# %%
train_images, train_masks, train_img_names = load_dataset_split(DATASET_PATH, 'train')
val_images, val_masks, val_img_names = load_dataset_split(DATASET_PATH, 'val')
test_images, test_masks, test_img_names = load_dataset_split(DATASET_PATH, 'test')

train_masks = train_masks[..., np.newaxis]
val_masks = val_masks[..., np.newaxis]
test_masks = test_masks[..., np.newaxis]

if config.INPUT_SHAPE[2] > 3:
    sal_maps = {}
    for split_name, img_names in zip(['train', 'val', 'test'], 
                                     [train_img_names, val_img_names, test_img_names]):
        # load sal_maps
        in_path = f'{DATASET_PATH}/{split_name}'\
                  f'/{split_name}_{config.BACKPROP_MODIFIER}_sal_patches'
        images = load_images_from_list(img_names, in_path) / 255.
        # save sal_maps
        sal_maps[split_name] = images[..., np.newaxis]
    
    train_images = np.concatenate([train_images, sal_maps['train']], axis=-1)
    val_images = np.concatenate([val_images, sal_maps['val']], axis=-1)
    test_images = np.concatenate([test_images, sal_maps['test']], axis=-1)
    
print(train_images.shape, train_images.dtype, train_images.min(), train_images.max())
print(val_images.shape, val_images.dtype, val_images.min(), val_images.max())
print(val_img_names[:3])
# Out:
# (200, 512, 512, 4) float64 0.0 1.0
# (100, 512, 512, 4) float64 0.0 1.0
# ['chicago12_5000_5000_0_0.png', 'chicago12_5000_5000_0_1.png', 'chicago12_5000_5000_0_2.png']

# %%
print(config.BACKPROP_MODIFIER)
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(train_images[1][:,:,:3])

if train_images.shape[2] > 3:
    plt.subplot(1, 3, 2)
    plt.imshow(train_images[1][:,:,3], cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(train_masks[1].squeeze(), cmap='gray')
plt.show()
# Out:
# None

# %% [markdown]
# ## 3. Instantiate a U-Net

# %%
model = unet(input_shape=config.INPUT_SHAPE)

# %% [markdown]
# ## 4. Train the model

# %%
# %%time
model_checkpoint = ModelCheckpoint(CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   verbose=0,
                                   save_best_only=True)

model.fit(x=train_images, y=train_masks,
          validation_data=[val_images, val_masks],
          batch_size=config.BATCH_SIZE,
          epochs=config.NUM_EPOCHS,
          callbacks=[model_checkpoint])
# Out:
# Train on 200 samples, validate on 100 samples
# Epoch 1/20
# 200/200 [==============================] - 195s 976ms/step - loss: 0.4790 - acc: 0.8158 - tf_jaccard: 0.0994 - tf_dice: 0.1481 - val_loss: 0.4606 - val_acc: 0.8221 - val_tf_jaccard: 0.2856 - val_tf_dice: 0.4128
# Epoch 2/20
# 200/200 [==============================] - 182s 909ms/step - loss: 0.3975 - acc: 0.8422 - tf_jaccard: 0.2649 - tf_dice: 0.3823 - val_loss: 0.4320 - val_acc: 0.7961 - val_tf_jaccard: 0.1585 - val_tf_dice: 0.2250
# Epoch 3/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.3454 - acc: 0.8575 - tf_jaccard: 0.3051 - tf_dice: 0.4336 - val_loss: 0.3343 - val_acc: 0.8535 - val_tf_jaccard: 0.3960 - val_tf_dice: 0.5279
# Epoch 4/20
# 200/200 [==============================] - 188s 938ms/step - loss: 0.3143 - acc: 0.8727 - tf_jaccard: 0.3883 - tf_dice: 0.5255 - val_loss: 0.3113 - val_acc: 0.8696 - val_tf_jaccard: 0.4337 - val_tf_dice: 0.5667
# Epoch 5/20
# 200/200 [==============================] - 183s 916ms/step - loss: 0.2980 - acc: 0.8816 - tf_jaccard: 0.4404 - tf_dice: 0.5798 - val_loss: 0.3065 - val_acc: 0.8716 - val_tf_jaccard: 0.4507 - val_tf_dice: 0.5833
# Epoch 6/20
# 200/200 [==============================] - 185s 926ms/step - loss: 0.2704 - acc: 0.8907 - tf_jaccard: 0.4789 - tf_dice: 0.6173 - val_loss: 0.3210 - val_acc: 0.8544 - val_tf_jaccard: 0.4599 - val_tf_dice: 0.5935
# Epoch 7/20
# 200/200 [==============================] - 183s 915ms/step - loss: 0.2529 - acc: 0.8986 - tf_jaccard: 0.5263 - tf_dice: 0.6629 - val_loss: 0.2992 - val_acc: 0.8751 - val_tf_jaccard: 0.4464 - val_tf_dice: 0.5875
# Epoch 8/20
# 200/200 [==============================] - 186s 928ms/step - loss: 0.2408 - acc: 0.9051 - tf_jaccard: 0.5497 - tf_dice: 0.6856 - val_loss: 0.2779 - val_acc: 0.8830 - val_tf_jaccard: 0.5255 - val_tf_dice: 0.6543
# Epoch 9/20
# 200/200 [==============================] - 187s 937ms/step - loss: 0.2287 - acc: 0.9108 - tf_jaccard: 0.5739 - tf_dice: 0.7063 - val_loss: 0.2616 - val_acc: 0.8940 - val_tf_jaccard: 0.5319 - val_tf_dice: 0.6573
# Epoch 10/20
# 200/200 [==============================] - 183s 917ms/step - loss: 0.2093 - acc: 0.9207 - tf_jaccard: 0.6022 - tf_dice: 0.7282 - val_loss: 0.2739 - val_acc: 0.8896 - val_tf_jaccard: 0.4826 - val_tf_dice: 0.6139
# Epoch 11/20
# 200/200 [==============================] - 184s 920ms/step - loss: 0.2164 - acc: 0.9159 - tf_jaccard: 0.5814 - tf_dice: 0.7101 - val_loss: 0.2319 - val_acc: 0.9066 - val_tf_jaccard: 0.5725 - val_tf_dice: 0.6898
# Epoch 12/20
# 200/200 [==============================] - 184s 919ms/step - loss: 0.2013 - acc: 0.9217 - tf_jaccard: 0.6021 - tf_dice: 0.7276 - val_loss: 0.2749 - val_acc: 0.8920 - val_tf_jaccard: 0.5462 - val_tf_dice: 0.6674
# Epoch 13/20
# 200/200 [==============================] - 184s 919ms/step - loss: 0.1900 - acc: 0.9261 - tf_jaccard: 0.6321 - tf_dice: 0.7551 - val_loss: 0.2244 - val_acc: 0.9118 - val_tf_jaccard: 0.6279 - val_tf_dice: 0.7438
# Epoch 14/20
# 200/200 [==============================] - 188s 938ms/step - loss: 0.1749 - acc: 0.9320 - tf_jaccard: 0.6471 - tf_dice: 0.7656 - val_loss: 0.2163 - val_acc: 0.9140 - val_tf_jaccard: 0.5992 - val_tf_dice: 0.7113
# Epoch 15/20
# 200/200 [==============================] - 184s 920ms/step - loss: 0.1842 - acc: 0.9282 - tf_jaccard: 0.6326 - tf_dice: 0.7520 - val_loss: 0.2213 - val_acc: 0.9113 - val_tf_jaccard: 0.5699 - val_tf_dice: 0.6841
# Epoch 16/20
# 200/200 [==============================] - 187s 937ms/step - loss: 0.1617 - acc: 0.9371 - tf_jaccard: 0.6657 - tf_dice: 0.7794 - val_loss: 0.2220 - val_acc: 0.9110 - val_tf_jaccard: 0.6185 - val_tf_dice: 0.7313
# Epoch 17/20
# 200/200 [==============================] - 185s 923ms/step - loss: 0.1550 - acc: 0.9402 - tf_jaccard: 0.6764 - tf_dice: 0.7874 - val_loss: 0.2349 - val_acc: 0.9059 - val_tf_jaccard: 0.5710 - val_tf_dice: 0.6918
# Epoch 18/20
# 200/200 [==============================] - 184s 920ms/step - loss: 0.1720 - acc: 0.9336 - tf_jaccard: 0.6509 - tf_dice: 0.7665 - val_loss: 0.2256 - val_acc: 0.9092 - val_tf_jaccard: 0.5944 - val_tf_dice: 0.7126
# Epoch 19/20
# 200/200 [==============================] - 187s 934ms/step - loss: 0.1521 - acc: 0.9405 - tf_jaccard: 0.6841 - tf_dice: 0.7934 - val_loss: 0.2240 - val_acc: 0.9147 - val_tf_jaccard: 0.6146 - val_tf_dice: 0.7287
# Epoch 20/20
# 200/200 [==============================] - 184s 919ms/step - loss: 0.1382 - acc: 0.9461 - tf_jaccard: 0.7064 - tf_dice: 0.8102 - val_loss: 0.2156 - val_acc: 0.9124 - val_tf_jaccard: 0.6044 - val_tf_dice: 0.7169
# CPU times: user 33min 53s, sys: 5min 40s, total: 39min 34s
# Wall time: 1h 2min 5s

# %%
print(dir(model.history))
#print(model.history.history)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'epoch', 'history', 'model', 'on_batch_begin', 'on_batch_end', 'on_epoch_begin', 'on_epoch_end', 'on_train_begin', 'on_train_end', 'params', 'set_model', 'set_params', 'validation_data']

# %%
write_json(model.history.history, LOGS_FILENAME)
logs = read_json(LOGS_FILENAME)

# %% [markdown]
# ### Some plots
# __Remember:__
# 1. we use patches (not initial images) for the training part;
# 2. accuracy is not a good metric for image segmentation evaluation (patches with small objects can have good accuracies with zero prediction for all pixels).

# %%
plot_train_val(logs['loss'], logs['val_loss'],
               fig_title='Loss',
               y_label='binary cross entropy')

plot_train_val(logs['tf_jaccard'], logs['val_tf_jaccard'],
               fig_title=f'IoU (thr={config.PRED_THR})',
               y_label='intersection over union')

plot_train_val(logs['tf_dice'], logs['val_tf_dice'],
               fig_title=f'Dice (thr={config.PRED_THR})',
               y_label='dice similarity coefficient')

plot_train_val(logs['acc'], logs['val_acc'],
               fig_title='Accuracy',
               y_label='accuracy')
