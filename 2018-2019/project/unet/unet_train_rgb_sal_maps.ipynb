# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os

from keras.callbacks import ModelCheckpoint
from unet import unet
from utils.dataset_utils import load_dataset_split, load_images_from_list
from utils.input_output import read_json, write_json
from utils.vis_utils import plot_image_mask_prediction, plot_train_val
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1.1 Change parameters of the experiment (and hyperparameters from ../config.py)

# %%
UNET_NAME = config.UNET_NAME
EXPERIMENT_NAME = config.EXPERIMENT_NAME
DATASET_PATH = f'../datasets/{config.DATASET_NAME}'

# %%
CHECKPOINTS_PATH = f'../checkpoints'
CHECKPOINT_FILENAME = f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}/{UNET_NAME}.hdf5'
LOGS_PATH = f'../logs'
LOGS_FILENAME = f'{LOGS_PATH}/{EXPERIMENT_NAME}.json'
RESULTS_PATH = f'../results/{EXPERIMENT_NAME}'

# %%
# !rm -rf $f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}'
os.makedirs(f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}')

# %%
a = np.ones([2,5,5,3])
b = np.zeros([2,5,5,1])
print(np.concatenate([a, b], axis=-1).shape)
# Out:
# (2, 5, 5, 4)

# %% [markdown]
# ## 2. Load the dataset splits

# %%
train_images, train_masks, train_img_names = load_dataset_split(DATASET_PATH, 'train')
val_images, val_masks, val_img_names = load_dataset_split(DATASET_PATH, 'val')
test_images, test_masks, test_img_names = load_dataset_split(DATASET_PATH, 'test')

train_masks = train_masks[..., np.newaxis]
val_masks = val_masks[..., np.newaxis]
test_masks = test_masks[..., np.newaxis]

if config.INPUT_SHAPE[2] > 3:
    sal_maps = {}
    for split_name, img_names in zip(['train', 'val', 'test'], 
                                     [train_img_names, val_img_names, test_img_names]):
        # load sal_maps
        in_path = f'{DATASET_PATH}/{split_name}'\
                  f'/{split_name}_{config.BACKPROP_MODIFIER}_sal_patches'
        images = load_images_from_list(img_names, in_path) / 255.
        # save sal_maps
        sal_maps[split_name] = images[..., np.newaxis]
    
    train_images = np.concatenate([train_images, sal_maps['train']], axis=-1)
    val_images = np.concatenate([val_images, sal_maps['val']], axis=-1)
    test_images = np.concatenate([test_images, sal_maps['test']], axis=-1)
    
print(train_images.shape, train_images.dtype, train_images.min(), train_images.max())
print(val_images.shape, val_images.dtype, val_images.min(), val_images.max())
print(val_img_names[:3])
# Out:
# (50, 512, 512, 4) float64 0.0 1.0
# (10, 512, 512, 4) float64 0.0 1.0
# ['2601177796_b8e280ac8a_334_500_0_0.png', '2802725781_52d0e4061a_500_336_0_0.png', '2803811473_1ba769690b_327_500_0_0.png']

# %%
print(config.BACKPROP_MODIFIER)
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(train_images[1][:,:,:3])

if train_images.shape[2] > 3:
    plt.subplot(1, 3, 2)
    plt.imshow(train_images[1][:,:,3], cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(train_masks[1].squeeze(), cmap='gray')
plt.show()
# Out:
# guided

# %% [markdown]
# ## 3. Instantiate a U-Net

# %%
model = unet(input_shape=config.INPUT_SHAPE)

# %% [markdown]
# ## 4. Train the model

# %%
# %%time
model_checkpoint = ModelCheckpoint(CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   verbose=0,
                                   save_best_only=True)

model.fit(x=train_images, y=train_masks,
          validation_data=[val_images, val_masks],
          batch_size=config.BATCH_SIZE,
          epochs=config.NUM_EPOCHS,
          callbacks=[model_checkpoint])
# Out:
# Train on 50 samples, validate on 10 samples
# Epoch 1/20
# 50/50 [==============================] - 87s 2s/step - loss: 0.4172 - acc: 0.8685 - tf_jaccard: 0.0798 - tf_dice: 0.1117 - val_loss: 0.1584 - val_acc: 0.9280 - val_tf_jaccard: 0.0000e+00 - val_tf_dice: 0.0000e+00
# Epoch 2/20
# 50/50 [==============================] - 44s 874ms/step - loss: 0.1895 - acc: 0.9200 - tf_jaccard: 0.2535 - tf_dice: 0.3368 - val_loss: 0.1403 - val_acc: 0.9280 - val_tf_jaccard: 2.6949e-04 - val_tf_dice: 5.3830e-04
# Epoch 3/20
# 50/50 [==============================] - 44s 874ms/step - loss: 0.1672 - acc: 0.9328 - tf_jaccard: 0.3591 - tf_dice: 0.4625 - val_loss: 0.1375 - val_acc: 0.9311 - val_tf_jaccard: 0.0454 - val_tf_dice: 0.0800
# Epoch 4/20
# 50/50 [==============================] - 44s 877ms/step - loss: 0.1560 - acc: 0.9398 - tf_jaccard: 0.4517 - tf_dice: 0.5562 - val_loss: 0.0826 - val_acc: 0.9797 - val_tf_jaccard: 0.6868 - val_tf_dice: 0.7757
# Epoch 5/20
# 50/50 [==============================] - 44s 884ms/step - loss: 0.1343 - acc: 0.9525 - tf_jaccard: 0.6249 - tf_dice: 0.7401 - val_loss: 0.1041 - val_acc: 0.9626 - val_tf_jaccard: 0.3818 - val_tf_dice: 0.5041
# Epoch 6/20
# 50/50 [==============================] - 44s 880ms/step - loss: 0.1295 - acc: 0.9544 - tf_jaccard: 0.6298 - tf_dice: 0.7380 - val_loss: 0.0601 - val_acc: 0.9818 - val_tf_jaccard: 0.6596 - val_tf_dice: 0.7534
# Epoch 7/20
# 50/50 [==============================] - 44s 888ms/step - loss: 0.1032 - acc: 0.9646 - tf_jaccard: 0.6593 - tf_dice: 0.7665 - val_loss: 0.0952 - val_acc: 0.9580 - val_tf_jaccard: 0.4151 - val_tf_dice: 0.5418
# Epoch 8/20
# 50/50 [==============================] - 44s 885ms/step - loss: 0.1013 - acc: 0.9629 - tf_jaccard: 0.6544 - tf_dice: 0.7583 - val_loss: 0.0703 - val_acc: 0.9702 - val_tf_jaccard: 0.4922 - val_tf_dice: 0.6171
# Epoch 9/20
# 50/50 [==============================] - 44s 885ms/step - loss: 0.1030 - acc: 0.9656 - tf_jaccard: 0.6606 - tf_dice: 0.7619 - val_loss: 0.0689 - val_acc: 0.9797 - val_tf_jaccard: 0.6365 - val_tf_dice: 0.7405
# Epoch 10/20
# 50/50 [==============================] - 44s 887ms/step - loss: 0.0932 - acc: 0.9657 - tf_jaccard: 0.6506 - tf_dice: 0.7490 - val_loss: 0.0636 - val_acc: 0.9826 - val_tf_jaccard: 0.6921 - val_tf_dice: 0.7772
# Epoch 11/20
# 50/50 [==============================] - 44s 887ms/step - loss: 0.1521 - acc: 0.9470 - tf_jaccard: 0.5410 - tf_dice: 0.6576 - val_loss: 0.0959 - val_acc: 0.9568 - val_tf_jaccard: 0.5304 - val_tf_dice: 0.6397
# Epoch 12/20
# 50/50 [==============================] - 45s 899ms/step - loss: 0.1251 - acc: 0.9524 - tf_jaccard: 0.6146 - tf_dice: 0.7240 - val_loss: 0.0741 - val_acc: 0.9684 - val_tf_jaccard: 0.5514 - val_tf_dice: 0.6605
# Epoch 13/20
# 50/50 [==============================] - 45s 891ms/step - loss: 0.0926 - acc: 0.9646 - tf_jaccard: 0.6720 - tf_dice: 0.7754 - val_loss: 0.1056 - val_acc: 0.9640 - val_tf_jaccard: 0.5052 - val_tf_dice: 0.6116
# Epoch 14/20
# 50/50 [==============================] - 45s 896ms/step - loss: 0.1208 - acc: 0.9491 - tf_jaccard: 0.5564 - tf_dice: 0.6809 - val_loss: 0.0907 - val_acc: 0.9509 - val_tf_jaccard: 0.3882 - val_tf_dice: 0.5109
# Epoch 15/20
# 50/50 [==============================] - 44s 888ms/step - loss: 0.0984 - acc: 0.9628 - tf_jaccard: 0.6620 - tf_dice: 0.7679 - val_loss: 0.0710 - val_acc: 0.9685 - val_tf_jaccard: 0.5799 - val_tf_dice: 0.6808
# Epoch 16/20
# 50/50 [==============================] - 44s 885ms/step - loss: 0.0917 - acc: 0.9623 - tf_jaccard: 0.6595 - tf_dice: 0.7695 - val_loss: 0.0848 - val_acc: 0.9669 - val_tf_jaccard: 0.5653 - val_tf_dice: 0.6661
# Epoch 17/20
# 50/50 [==============================] - 44s 887ms/step - loss: 0.0808 - acc: 0.9669 - tf_jaccard: 0.6780 - tf_dice: 0.7799 - val_loss: 0.0535 - val_acc: 0.9803 - val_tf_jaccard: 0.6805 - val_tf_dice: 0.7663
# Epoch 18/20
# 50/50 [==============================] - 44s 883ms/step - loss: 0.0725 - acc: 0.9708 - tf_jaccard: 0.6969 - tf_dice: 0.7950 - val_loss: 0.0625 - val_acc: 0.9767 - val_tf_jaccard: 0.6137 - val_tf_dice: 0.7065
# Epoch 19/20
# 50/50 [==============================] - 44s 886ms/step - loss: 0.0755 - acc: 0.9707 - tf_jaccard: 0.6945 - tf_dice: 0.7942 - val_loss: 0.0565 - val_acc: 0.9785 - val_tf_jaccard: 0.6627 - val_tf_dice: 0.7513
# Epoch 20/20
# 50/50 [==============================] - 44s 884ms/step - loss: 0.0777 - acc: 0.9682 - tf_jaccard: 0.6929 - tf_dice: 0.7953 - val_loss: 0.0559 - val_acc: 0.9768 - val_tf_jaccard: 0.6275 - val_tf_dice: 0.7198
# CPU times: user 12min 48s, sys: 1min 9s, total: 13min 58s
# Wall time: 16min 44s

# %%
print(dir(model.history))
#print(model.history.history)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'epoch', 'history', 'model', 'on_batch_begin', 'on_batch_end', 'on_epoch_begin', 'on_epoch_end', 'on_train_begin', 'on_train_end', 'params', 'set_model', 'set_params', 'validation_data']

# %%
write_json(model.history.history, LOGS_FILENAME)
logs = read_json(LOGS_FILENAME)

# %% [markdown]
# ### Some plots
# __Remember:__
# 1. we use patches (not initial images) for the training part;
# 2. accuracy is not a good metric for image segmentation evaluation (patches with small objects can have good accuracies with zero prediction for all pixels).

# %%
plot_train_val(logs['loss'], logs['val_loss'],
               fig_title='Loss',
               y_label='binary cross entropy')

plot_train_val(logs['tf_jaccard'], logs['val_tf_jaccard'],
               fig_title=f'IoU (thr={config.PRED_THR})',
               y_label='intersection over union')

plot_train_val(logs['tf_dice'], logs['val_tf_dice'],
               fig_title=f'Dice (thr={config.PRED_THR})',
               y_label='dice similarity coefficient')

plot_train_val(logs['acc'], logs['val_acc'],
               fig_title='Accuracy',
               y_label='accuracy')
