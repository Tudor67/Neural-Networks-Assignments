# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os

from keras.callbacks import ModelCheckpoint
from unet import unet
from utils.dataset_utils import load_dataset_split, load_images_from_list
from utils.input_output import read_json, write_json
from utils.vis_utils import plot_image_mask_prediction, plot_train_val
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1.1 Change parameters of the experiment (and hyperparameters from ../config.py)

# %%
UNET_NAME = config.UNET_NAME
EXPERIMENT_NAME = config.EXPERIMENT_NAME
DATASET_PATH = f'../datasets/{config.DATASET_NAME}'

# %%
CHECKPOINTS_PATH = f'../checkpoints'
CHECKPOINT_FILENAME = f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}/{UNET_NAME}.hdf5'
LOGS_PATH = f'../logs'
LOGS_FILENAME = f'{LOGS_PATH}/{EXPERIMENT_NAME}.json'
RESULTS_PATH = f'../results/{EXPERIMENT_NAME}'

# %%
# !rm -rf $f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}'
os.makedirs(f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}')

# %%
print(EXPERIMENT_NAME)
# Out:
# inria_aerial/subset_chicago/UNet_RGB_SAL_MAP_GUIDED

# %%
a = np.ones([2,5,5,3])
b = np.zeros([2,5,5,1])
print(np.concatenate([a, b], axis=-1).shape)
# Out:
# (2, 5, 5, 4)

# %% [markdown]
# ## 2. Load the dataset splits

# %%
train_images, train_masks, train_img_names = load_dataset_split(DATASET_PATH, 'train')
val_images, val_masks, val_img_names = load_dataset_split(DATASET_PATH, 'val')
test_images, test_masks, test_img_names = load_dataset_split(DATASET_PATH, 'test')

train_masks = train_masks[..., np.newaxis]
val_masks = val_masks[..., np.newaxis]
test_masks = test_masks[..., np.newaxis]

if config.INPUT_SHAPE[2] > 3:
    sal_maps = {}
    for split_name, img_names in zip(['train', 'val', 'test'], 
                                     [train_img_names, val_img_names, test_img_names]):
        # load sal_maps
        in_path = f'{DATASET_PATH}/{split_name}'\
                  f'/{split_name}_{config.BACKPROP_MODIFIER}_sal_patches'
        images = load_images_from_list(img_names, in_path) / 255.
        # save sal_maps
        sal_maps[split_name] = images[..., np.newaxis]
    
    train_images = np.concatenate([train_images, sal_maps['train']], axis=-1)
    val_images = np.concatenate([val_images, sal_maps['val']], axis=-1)
    test_images = np.concatenate([test_images, sal_maps['test']], axis=-1)
    
print(train_images.shape, train_images.dtype, train_images.min(), train_images.max())
print(val_images.shape, val_images.dtype, val_images.min(), val_images.max())
print(val_img_names[:3])
# Out:
# (200, 512, 512, 4) float64 0.0 1.0
# (100, 512, 512, 4) float64 0.0 1.0
# ['chicago12_5000_5000_0_0.png', 'chicago12_5000_5000_0_1.png', 'chicago12_5000_5000_0_2.png']

# %%
print(config.BACKPROP_MODIFIER)
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(train_images[1][:,:,:3])

if train_images.shape[2] > 3:
    plt.subplot(1, 3, 2)
    plt.imshow(train_images[1][:,:,3], cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(train_masks[1].squeeze(), cmap='gray')
plt.show()
# Out:
# guided

# %% [markdown]
# ## 3. Instantiate a U-Net

# %%
model = unet(input_shape=config.INPUT_SHAPE)

# %% [markdown]
# ## 4. Train the model

# %%
# %%time
model_checkpoint = ModelCheckpoint(CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   verbose=0,
                                   save_best_only=True)

model.fit(x=train_images, y=train_masks,
          validation_data=[val_images, val_masks],
          batch_size=config.BATCH_SIZE,
          epochs=config.NUM_EPOCHS,
          callbacks=[model_checkpoint])
# Out:
# Train on 200 samples, validate on 100 samples
# Epoch 1/20
# 200/200 [==============================] - 193s 967ms/step - loss: 0.5099 - acc: 0.8041 - tf_jaccard: 0.0410 - tf_dice: 0.0627 - val_loss: 0.4082 - val_acc: 0.8057 - val_tf_jaccard: 0.1768 - val_tf_dice: 0.2625
# Epoch 2/20
# 200/200 [==============================] - 182s 909ms/step - loss: 0.3775 - acc: 0.8394 - tf_jaccard: 0.2584 - tf_dice: 0.3714 - val_loss: 0.3482 - val_acc: 0.8544 - val_tf_jaccard: 0.3942 - val_tf_dice: 0.5278
# Epoch 3/20
# 200/200 [==============================] - 182s 912ms/step - loss: 0.3571 - acc: 0.8549 - tf_jaccard: 0.3066 - tf_dice: 0.4344 - val_loss: 0.3362 - val_acc: 0.8593 - val_tf_jaccard: 0.3984 - val_tf_dice: 0.5321
# Epoch 4/20
# 200/200 [==============================] - 187s 933ms/step - loss: 0.3285 - acc: 0.8660 - tf_jaccard: 0.3427 - tf_dice: 0.4704 - val_loss: 0.3241 - val_acc: 0.8685 - val_tf_jaccard: 0.4212 - val_tf_dice: 0.5534
# Epoch 5/20
# 200/200 [==============================] - 183s 915ms/step - loss: 0.2912 - acc: 0.8865 - tf_jaccard: 0.4654 - tf_dice: 0.6066 - val_loss: 0.3366 - val_acc: 0.8534 - val_tf_jaccard: 0.3700 - val_tf_dice: 0.5039
# Epoch 6/20
# 200/200 [==============================] - 183s 914ms/step - loss: 0.2678 - acc: 0.8971 - tf_jaccard: 0.5003 - tf_dice: 0.6418 - val_loss: 0.2950 - val_acc: 0.8756 - val_tf_jaccard: 0.4819 - val_tf_dice: 0.6155
# Epoch 7/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.2625 - acc: 0.8972 - tf_jaccard: 0.5134 - tf_dice: 0.6535 - val_loss: 0.2985 - val_acc: 0.8768 - val_tf_jaccard: 0.4471 - val_tf_dice: 0.5856
# Epoch 8/20
# 200/200 [==============================] - 186s 932ms/step - loss: 0.2338 - acc: 0.9116 - tf_jaccard: 0.5708 - tf_dice: 0.7045 - val_loss: 0.2659 - val_acc: 0.8953 - val_tf_jaccard: 0.5236 - val_tf_dice: 0.6499
# Epoch 9/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.2170 - acc: 0.9185 - tf_jaccard: 0.6012 - tf_dice: 0.7298 - val_loss: 0.2523 - val_acc: 0.9022 - val_tf_jaccard: 0.5418 - val_tf_dice: 0.6653
# Epoch 10/20
# 200/200 [==============================] - 183s 914ms/step - loss: 0.2034 - acc: 0.9228 - tf_jaccard: 0.6156 - tf_dice: 0.7412 - val_loss: 0.2416 - val_acc: 0.9043 - val_tf_jaccard: 0.5663 - val_tf_dice: 0.6842
# Epoch 11/20
# 200/200 [==============================] - 186s 930ms/step - loss: 0.2018 - acc: 0.9219 - tf_jaccard: 0.6130 - tf_dice: 0.7381 - val_loss: 0.2401 - val_acc: 0.9052 - val_tf_jaccard: 0.5576 - val_tf_dice: 0.6822
# Epoch 12/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.1888 - acc: 0.9292 - tf_jaccard: 0.6444 - tf_dice: 0.7651 - val_loss: 0.2178 - val_acc: 0.9131 - val_tf_jaccard: 0.6001 - val_tf_dice: 0.7135
# Epoch 13/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.1903 - acc: 0.9277 - tf_jaccard: 0.6383 - tf_dice: 0.7606 - val_loss: 0.2230 - val_acc: 0.9135 - val_tf_jaccard: 0.5980 - val_tf_dice: 0.7129
# Epoch 14/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.1834 - acc: 0.9285 - tf_jaccard: 0.6376 - tf_dice: 0.7586 - val_loss: 0.2297 - val_acc: 0.9106 - val_tf_jaccard: 0.5757 - val_tf_dice: 0.6905
# Epoch 15/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.1681 - acc: 0.9352 - tf_jaccard: 0.6658 - tf_dice: 0.7825 - val_loss: 0.2161 - val_acc: 0.9166 - val_tf_jaccard: 0.6150 - val_tf_dice: 0.7283
# Epoch 16/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.1526 - acc: 0.9411 - tf_jaccard: 0.6877 - tf_dice: 0.7988 - val_loss: 0.2197 - val_acc: 0.9145 - val_tf_jaccard: 0.5959 - val_tf_dice: 0.7080
# Epoch 17/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.1534 - acc: 0.9416 - tf_jaccard: 0.6854 - tf_dice: 0.7937 - val_loss: 0.2329 - val_acc: 0.9092 - val_tf_jaccard: 0.5997 - val_tf_dice: 0.7147
# Epoch 18/20
# 200/200 [==============================] - 185s 926ms/step - loss: 0.1592 - acc: 0.9378 - tf_jaccard: 0.6742 - tf_dice: 0.7871 - val_loss: 0.2230 - val_acc: 0.9154 - val_tf_jaccard: 0.6263 - val_tf_dice: 0.7393
# Epoch 19/20
# 200/200 [==============================] - 185s 927ms/step - loss: 0.1309 - acc: 0.9494 - tf_jaccard: 0.7173 - tf_dice: 0.8195 - val_loss: 0.2370 - val_acc: 0.9109 - val_tf_jaccard: 0.5912 - val_tf_dice: 0.7099
# Epoch 20/20
# 200/200 [==============================] - 183s 913ms/step - loss: 0.1381 - acc: 0.9465 - tf_jaccard: 0.7073 - tf_dice: 0.8114 - val_loss: 0.2358 - val_acc: 0.9065 - val_tf_jaccard: 0.5730 - val_tf_dice: 0.6965
# CPU times: user 33min 25s, sys: 5min 50s, total: 39min 15s
# Wall time: 1h 1min 40s

# %%
print(dir(model.history))
#print(model.history.history)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'epoch', 'history', 'model', 'on_batch_begin', 'on_batch_end', 'on_epoch_begin', 'on_epoch_end', 'on_train_begin', 'on_train_end', 'params', 'set_model', 'set_params', 'validation_data']

# %%
write_json(model.history.history, LOGS_FILENAME)
logs = read_json(LOGS_FILENAME)

# %% [markdown]
# ### Some plots
# __Remember:__
# 1. we use patches (not initial images) for the training part;
# 2. accuracy is not a good metric for image segmentation evaluation (patches with small objects can have good accuracies with zero prediction for all pixels).

# %%
plot_train_val(logs['loss'], logs['val_loss'],
               fig_title='Loss',
               y_label='binary cross entropy')

plot_train_val(logs['tf_jaccard'], logs['val_tf_jaccard'],
               fig_title=f'IoU (thr={config.PRED_THR})',
               y_label='intersection over union')

plot_train_val(logs['tf_dice'], logs['val_tf_dice'],
               fig_title=f'Dice (thr={config.PRED_THR})',
               y_label='dice similarity coefficient')

plot_train_val(logs['acc'], logs['val_acc'],
               fig_title='Accuracy',
               y_label='accuracy')
