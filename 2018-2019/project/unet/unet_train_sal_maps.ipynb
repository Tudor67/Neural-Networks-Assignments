# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os

from keras.callbacks import ModelCheckpoint
from unet import unet
from utils.dataset_utils import load_dataset_split, load_images_from_list
from utils.input_output import read_json, write_json
from utils.vis_utils import plot_image_mask_prediction, plot_train_val
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1.1 Change parameters of the experiment (and hyperparameters from ../config.py)

# %%
UNET_NAME = config.UNET_NAME
EXPERIMENT_NAME = config.EXPERIMENT_NAME
DATASET_PATH = f'../datasets/{config.DATASET_NAME}'

# %%
CHECKPOINTS_PATH = f'../checkpoints'
CHECKPOINT_FILENAME = f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}/{UNET_NAME}.hdf5'
LOGS_PATH = f'../logs'
LOGS_FILENAME = f'{LOGS_PATH}/{EXPERIMENT_NAME}.json'
RESULTS_PATH = f'../results/{EXPERIMENT_NAME}'

# %%
# !rm -rf $f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}'
os.makedirs(f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}')

# %%
a = np.ones([2,5,5,3])
b = np.zeros([2,5,5,1])
print(np.concatenate([a, b], axis=-1).shape)
# Out:
# (2, 5, 5, 4)

# %% [markdown]
# ## 2. Load the dataset splits

# %%
train_images, train_masks, train_img_names = load_dataset_split(DATASET_PATH, 'train')
val_images, val_masks, val_img_names = load_dataset_split(DATASET_PATH, 'val')
test_images, test_masks, test_img_names = load_dataset_split(DATASET_PATH, 'test')

train_masks = train_masks[..., np.newaxis]
val_masks = val_masks[..., np.newaxis]
test_masks = test_masks[..., np.newaxis]

if config.INPUT == 'sal_map':
    sal_maps = {}
    for split_name, img_names in zip(['train', 'val', 'test'], 
                                     [train_img_names, val_img_names, test_img_names]):
        # load sal_maps
        in_path = f'{DATASET_PATH}/{split_name}'\
                  f'/{split_name}_{config.BACKPROP_MODIFIER}_sal_patches'
        images = load_images_from_list(img_names, in_path) / 255.
        # save sal_maps
        sal_maps[split_name] = images[..., np.newaxis]
    
    train_images = np.concatenate([train_images, sal_maps['train']], axis=-1)
    val_images = np.concatenate([val_images, sal_maps['val']], axis=-1)
    test_images = np.concatenate([test_images, sal_maps['test']], axis=-1)
    
print(train_images.shape, train_images.dtype, train_images.min(), train_images.max())
print(val_images.shape, val_images.dtype, val_images.min(), val_images.max())
print(val_img_names[:3])
# Out:
# (50, 512, 512, 4) float64 0.0 1.0
# (10, 512, 512, 4) float64 0.0 1.0
# ['2601177796_b8e280ac8a_334_500_0_0.png', '2802725781_52d0e4061a_500_336_0_0.png', '2803811473_1ba769690b_327_500_0_0.png']

# %%
print(config.BACKPROP_MODIFIER)
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(train_images[1][:,:,:3])

if train_images.shape[2] > 3:
    plt.subplot(1, 3, 2)
    plt.imshow(train_images[1][:,:,3], cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(train_masks[1].squeeze(), cmap='gray')
plt.show()
# Out:
# guided

# %% [markdown]
# ## 3. Instantiate a U-Net

# %%
model = unet(input_shape=config.INPUT_SHAPE)

# %% [markdown]
# ## 4. Train the model

# %%
# %%time
model_checkpoint = ModelCheckpoint(CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   verbose=0,
                                   save_best_only=True)

model.fit(x=train_images[..., 3:], y=train_masks,
          validation_data=[val_images[..., 3:], val_masks],
          batch_size=config.BATCH_SIZE,
          epochs=config.NUM_EPOCHS,
          callbacks=[model_checkpoint])
# Out:
# Train on 50 samples, validate on 10 samples
# Epoch 1/20
# 50/50 [==============================] - 55s 1s/step - loss: 0.4231 - acc: 0.9040 - tf_jaccard: 1.3307e-05 - tf_dice: 2.6607e-05 - val_loss: 0.1665 - val_acc: 0.9280 - val_tf_jaccard: 0.0000e+00 - val_tf_dice: 0.0000e+00
# Epoch 2/20
# 50/50 [==============================] - 44s 873ms/step - loss: 0.2426 - acc: 0.9040 - tf_jaccard: 8.6284e-04 - tf_dice: 0.0017 - val_loss: 0.1570 - val_acc: 0.9280 - val_tf_jaccard: 0.0000e+00 - val_tf_dice: 0.0000e+00
# Epoch 3/20
# 50/50 [==============================] - 44s 874ms/step - loss: 0.2628 - acc: 0.9043 - tf_jaccard: 0.0247 - tf_dice: 0.0459 - val_loss: 0.2327 - val_acc: 0.9305 - val_tf_jaccard: 0.1532 - val_tf_dice: 0.2481
# Epoch 4/20
# 50/50 [==============================] - 44s 880ms/step - loss: 0.2113 - acc: 0.9035 - tf_jaccard: 0.1423 - tf_dice: 0.2259 - val_loss: 0.1841 - val_acc: 0.9289 - val_tf_jaccard: 0.0503 - val_tf_dice: 0.0903
# Epoch 5/20
# 50/50 [==============================] - 44s 878ms/step - loss: 0.1885 - acc: 0.9059 - tf_jaccard: 0.0455 - tf_dice: 0.0800 - val_loss: 0.1830 - val_acc: 0.9327 - val_tf_jaccard: 0.2806 - val_tf_dice: 0.4164
# Epoch 6/20
# 50/50 [==============================] - 44s 875ms/step - loss: 0.1975 - acc: 0.9076 - tf_jaccard: 0.1790 - tf_dice: 0.2816 - val_loss: 0.1204 - val_acc: 0.9380 - val_tf_jaccard: 0.2554 - val_tf_dice: 0.3872
# Epoch 7/20
# 50/50 [==============================] - 44s 878ms/step - loss: 0.1834 - acc: 0.9082 - tf_jaccard: 0.2376 - tf_dice: 0.3632 - val_loss: 0.1628 - val_acc: 0.9401 - val_tf_jaccard: 0.3426 - val_tf_dice: 0.4859
# Epoch 8/20
# 50/50 [==============================] - 44s 874ms/step - loss: 0.1817 - acc: 0.9124 - tf_jaccard: 0.2748 - tf_dice: 0.4062 - val_loss: 0.1314 - val_acc: 0.9395 - val_tf_jaccard: 0.2946 - val_tf_dice: 0.4341
# Epoch 9/20
# 50/50 [==============================] - 44s 882ms/step - loss: 0.1697 - acc: 0.9138 - tf_jaccard: 0.2564 - tf_dice: 0.3919 - val_loss: 0.1313 - val_acc: 0.9398 - val_tf_jaccard: 0.4001 - val_tf_dice: 0.5494
# Epoch 10/20
# 50/50 [==============================] - 44s 886ms/step - loss: 0.1744 - acc: 0.9158 - tf_jaccard: 0.3301 - tf_dice: 0.4749 - val_loss: 0.1288 - val_acc: 0.9397 - val_tf_jaccard: 0.4059 - val_tf_dice: 0.5499
# Epoch 11/20
# 50/50 [==============================] - 44s 885ms/step - loss: 0.1850 - acc: 0.9164 - tf_jaccard: 0.3311 - tf_dice: 0.4731 - val_loss: 0.1188 - val_acc: 0.9454 - val_tf_jaccard: 0.3630 - val_tf_dice: 0.5139
# Epoch 12/20
# 50/50 [==============================] - 43s 861ms/step - loss: 0.1716 - acc: 0.9173 - tf_jaccard: 0.3248 - tf_dice: 0.4677 - val_loss: 0.1137 - val_acc: 0.9497 - val_tf_jaccard: 0.4279 - val_tf_dice: 0.5791
# Epoch 13/20
# 50/50 [==============================] - 42s 848ms/step - loss: 0.1570 - acc: 0.9241 - tf_jaccard: 0.3674 - tf_dice: 0.5118 - val_loss: 0.1016 - val_acc: 0.9537 - val_tf_jaccard: 0.4339 - val_tf_dice: 0.5853
# Epoch 14/20
# 50/50 [==============================] - 44s 875ms/step - loss: 0.1523 - acc: 0.9241 - tf_jaccard: 0.4043 - tf_dice: 0.5494 - val_loss: 0.1093 - val_acc: 0.9560 - val_tf_jaccard: 0.4789 - val_tf_dice: 0.6212
# Epoch 15/20
# 50/50 [==============================] - 44s 882ms/step - loss: 0.1489 - acc: 0.9318 - tf_jaccard: 0.4239 - tf_dice: 0.5736 - val_loss: 0.1474 - val_acc: 0.9412 - val_tf_jaccard: 0.4540 - val_tf_dice: 0.5802
# Epoch 16/20
# 50/50 [==============================] - 45s 890ms/step - loss: 0.1592 - acc: 0.9283 - tf_jaccard: 0.4319 - tf_dice: 0.5783 - val_loss: 0.1267 - val_acc: 0.9455 - val_tf_jaccard: 0.3512 - val_tf_dice: 0.4983
# Epoch 17/20
# 50/50 [==============================] - 44s 889ms/step - loss: 0.1570 - acc: 0.9250 - tf_jaccard: 0.3663 - tf_dice: 0.5155 - val_loss: 0.1390 - val_acc: 0.9464 - val_tf_jaccard: 0.4404 - val_tf_dice: 0.5767
# Epoch 18/20
# 50/50 [==============================] - 44s 881ms/step - loss: 0.1510 - acc: 0.9321 - tf_jaccard: 0.4440 - tf_dice: 0.5911 - val_loss: 0.1406 - val_acc: 0.9531 - val_tf_jaccard: 0.4778 - val_tf_dice: 0.6080
# Epoch 19/20
# 50/50 [==============================] - 43s 864ms/step - loss: 0.1349 - acc: 0.9384 - tf_jaccard: 0.4684 - tf_dice: 0.6104 - val_loss: 0.0956 - val_acc: 0.9564 - val_tf_jaccard: 0.4123 - val_tf_dice: 0.5625
# Epoch 20/20
# 50/50 [==============================] - 44s 872ms/step - loss: 0.1404 - acc: 0.9312 - tf_jaccard: 0.4544 - tf_dice: 0.6048 - val_loss: 0.1136 - val_acc: 0.9571 - val_tf_jaccard: 0.4812 - val_tf_dice: 0.6104
# CPU times: user 8min 51s, sys: 1min 29s, total: 10min 21s
# Wall time: 15min 4s

# %%
print(dir(model.history))
#print(model.history.history)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'epoch', 'history', 'model', 'on_batch_begin', 'on_batch_end', 'on_epoch_begin', 'on_epoch_end', 'on_train_begin', 'on_train_end', 'params', 'set_model', 'set_params', 'validation_data']

# %%
write_json(model.history.history, LOGS_FILENAME)
logs = read_json(LOGS_FILENAME)

# %% [markdown]
# ### Some plots
# __Remember:__
# 1. we use patches (not initial images) for the training part;
# 2. accuracy is not a good metric for image segmentation evaluation (patches with small objects can have good accuracies with zero prediction for all pixels).

# %%
plot_train_val(logs['loss'], logs['val_loss'],
               fig_title='Loss',
               y_label='binary cross entropy')

plot_train_val(logs['tf_jaccard'], logs['val_tf_jaccard'],
               fig_title=f'IoU (thr={config.PRED_THR})',
               y_label='intersection over union')

plot_train_val(logs['tf_dice'], logs['val_tf_dice'],
               fig_title=f'Dice (thr={config.PRED_THR})',
               y_label='dice similarity coefficient')

plot_train_val(logs['acc'], logs['val_acc'],
               fig_title='Accuracy',
               y_label='accuracy')
