# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append('..')

# %%
import config
import matplotlib.pyplot as plt
import numpy as np
import os

from keras.callbacks import ModelCheckpoint
from unet import unet
from utils.dataset_utils import load_dataset_split, load_images_from_list
from utils.input_output import read_json, write_json
from utils.vis_utils import plot_image_mask_prediction, plot_train_val
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1.1 Change parameters of the experiment (and hyperparameters from ../config.py)

# %%
UNET_NAME = config.UNET_NAME
EXPERIMENT_NAME = config.EXPERIMENT_NAME
DATASET_PATH = f'../datasets/{config.DATASET_NAME}'

# %%
CHECKPOINTS_PATH = f'../checkpoints'
CHECKPOINT_FILENAME = f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}/{UNET_NAME}.hdf5'
LOGS_PATH = f'../logs'
LOGS_FILENAME = f'{LOGS_PATH}/{EXPERIMENT_NAME}.json'
RESULTS_PATH = f'../results/{EXPERIMENT_NAME}'

# %%
# !rm -rf $f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}'
os.makedirs(f'{CHECKPOINTS_PATH}/{EXPERIMENT_NAME}')

# %%
print(EXPERIMENT_NAME)
# Out:
# inria_aerial/subset_chicago/UNet_SAL_MAP_GUIDED

# %%
a = np.ones([2,5,5,3])
b = np.zeros([2,5,5,1])
print(np.concatenate([a, b], axis=-1).shape)
# Out:
# (2, 5, 5, 4)

# %% [markdown]
# ## 2. Load the dataset splits

# %%
train_images, train_masks, train_img_names = load_dataset_split(DATASET_PATH, 'train')
val_images, val_masks, val_img_names = load_dataset_split(DATASET_PATH, 'val')
test_images, test_masks, test_img_names = load_dataset_split(DATASET_PATH, 'test')

train_masks = train_masks[..., np.newaxis]
val_masks = val_masks[..., np.newaxis]
test_masks = test_masks[..., np.newaxis]

if config.INPUT == 'sal_map':
    sal_maps = {}
    for split_name, img_names in zip(['train', 'val', 'test'], 
                                     [train_img_names, val_img_names, test_img_names]):
        # load sal_maps
        in_path = f'{DATASET_PATH}/{split_name}'\
                  f'/{split_name}_{config.BACKPROP_MODIFIER}_sal_patches'
        images = load_images_from_list(img_names, in_path) / 255.
        # save sal_maps
        sal_maps[split_name] = images[..., np.newaxis]
    
    train_images = np.concatenate([train_images, sal_maps['train']], axis=-1)
    val_images = np.concatenate([val_images, sal_maps['val']], axis=-1)
    test_images = np.concatenate([test_images, sal_maps['test']], axis=-1)
    
print(train_images.shape, train_images.dtype, train_images.min(), train_images.max())
print(val_images.shape, val_images.dtype, val_images.min(), val_images.max())
print(val_img_names[:3])
# Out:
# (200, 512, 512, 4) float64 0.0 1.0
# (100, 512, 512, 4) float64 0.0 1.0
# ['chicago12_5000_5000_0_0.png', 'chicago12_5000_5000_0_1.png', 'chicago12_5000_5000_0_2.png']

# %%
print(config.BACKPROP_MODIFIER)
plt.figure(figsize=(10, 5))
plt.subplot(1, 3, 1)
plt.imshow(train_images[1][:,:,:3])

if train_images.shape[2] > 3:
    plt.subplot(1, 3, 2)
    plt.imshow(train_images[1][:,:,3], cmap='gray')
plt.subplot(1, 3, 3)
plt.imshow(train_masks[1].squeeze(), cmap='gray')
plt.show()
# Out:
# guided

# %% [markdown]
# ## 3. Instantiate a U-Net

# %%
model = unet(input_shape=config.INPUT_SHAPE)

# %% [markdown]
# ## 4. Train the model

# %%
# %%time
model_checkpoint = ModelCheckpoint(CHECKPOINT_FILENAME,
                                   monitor='val_loss',
                                   verbose=0,
                                   save_best_only=True)

model.fit(x=train_images[..., 3:], y=train_masks,
          validation_data=[val_images[..., 3:], val_masks],
          batch_size=config.BATCH_SIZE,
          epochs=config.NUM_EPOCHS,
          callbacks=[model_checkpoint])
# Out:
# Train on 200 samples, validate on 100 samples
# Epoch 1/20
# 200/200 [==============================] - 194s 972ms/step - loss: 0.5377 - acc: 0.8091 - tf_jaccard: 0.0250 - tf_dice: 0.0250 - val_loss: 0.5569 - val_acc: 0.7765 - val_tf_jaccard: 0.0900 - val_tf_dice: 0.0900
# Epoch 2/20
# 200/200 [==============================] - 181s 905ms/step - loss: 0.4989 - acc: 0.8091 - tf_jaccard: 0.0250 - tf_dice: 0.0250 - val_loss: 0.5051 - val_acc: 0.7765 - val_tf_jaccard: 0.0900 - val_tf_dice: 0.0900
# Epoch 3/20
# 200/200 [==============================] - 182s 908ms/step - loss: 0.4686 - acc: 0.8091 - tf_jaccard: 0.0250 - tf_dice: 0.0250 - val_loss: 0.4974 - val_acc: 0.7765 - val_tf_jaccard: 0.0900 - val_tf_dice: 0.0900
# Epoch 4/20
# 200/200 [==============================] - 182s 910ms/step - loss: 0.4626 - acc: 0.8090 - tf_jaccard: 0.0253 - tf_dice: 0.0255 - val_loss: 0.4710 - val_acc: 0.7765 - val_tf_jaccard: 0.0900 - val_tf_dice: 0.0900
# Epoch 5/20
# 200/200 [==============================] - 182s 909ms/step - loss: 0.4266 - acc: 0.8051 - tf_jaccard: 0.0825 - tf_dice: 0.1278 - val_loss: 0.5118 - val_acc: 0.7765 - val_tf_jaccard: 0.0805 - val_tf_dice: 0.0809
# Epoch 6/20
# 200/200 [==============================] - 182s 912ms/step - loss: 0.4217 - acc: 0.8130 - tf_jaccard: 0.0892 - tf_dice: 0.1322 - val_loss: 0.4690 - val_acc: 0.7769 - val_tf_jaccard: 0.0725 - val_tf_dice: 0.0750
# Epoch 7/20
# 200/200 [==============================] - 182s 910ms/step - loss: 0.3937 - acc: 0.8179 - tf_jaccard: 0.1686 - tf_dice: 0.2576 - val_loss: 0.4677 - val_acc: 0.7765 - val_tf_jaccard: 0.0900 - val_tf_dice: 0.0900
# Epoch 8/20
# 200/200 [==============================] - 182s 911ms/step - loss: 0.3708 - acc: 0.8316 - tf_jaccard: 0.2364 - tf_dice: 0.3463 - val_loss: 0.4416 - val_acc: 0.8259 - val_tf_jaccard: 0.3182 - val_tf_dice: 0.4496
# Epoch 9/20
# 200/200 [==============================] - 182s 911ms/step - loss: 0.3444 - acc: 0.8474 - tf_jaccard: 0.3362 - tf_dice: 0.4785 - val_loss: 0.3770 - val_acc: 0.8404 - val_tf_jaccard: 0.3502 - val_tf_dice: 0.4850
# Epoch 10/20
# 200/200 [==============================] - 182s 911ms/step - loss: 0.3040 - acc: 0.8699 - tf_jaccard: 0.4102 - tf_dice: 0.5588 - val_loss: 0.3589 - val_acc: 0.8506 - val_tf_jaccard: 0.3884 - val_tf_dice: 0.5253
# Epoch 11/20
# 200/200 [==============================] - 185s 925ms/step - loss: 0.2923 - acc: 0.8772 - tf_jaccard: 0.4357 - tf_dice: 0.5812 - val_loss: 0.3312 - val_acc: 0.8610 - val_tf_jaccard: 0.4531 - val_tf_dice: 0.5881
# Epoch 12/20
# 200/200 [==============================] - 182s 911ms/step - loss: 0.2849 - acc: 0.8802 - tf_jaccard: 0.4609 - tf_dice: 0.6013 - val_loss: 0.3643 - val_acc: 0.8410 - val_tf_jaccard: 0.3322 - val_tf_dice: 0.4606
# Epoch 13/20
# 200/200 [==============================] - 182s 912ms/step - loss: 0.2792 - acc: 0.8852 - tf_jaccard: 0.4628 - tf_dice: 0.6080 - val_loss: 0.3459 - val_acc: 0.8515 - val_tf_jaccard: 0.3864 - val_tf_dice: 0.5227
# Epoch 14/20
# 200/200 [==============================] - 182s 910ms/step - loss: 0.2450 - acc: 0.9001 - tf_jaccard: 0.5203 - tf_dice: 0.6599 - val_loss: 0.3317 - val_acc: 0.8700 - val_tf_jaccard: 0.4489 - val_tf_dice: 0.5827
# Epoch 15/20
# 200/200 [==============================] - 182s 911ms/step - loss: 0.2173 - acc: 0.9127 - tf_jaccard: 0.5669 - tf_dice: 0.7004 - val_loss: 0.3375 - val_acc: 0.8711 - val_tf_jaccard: 0.4626 - val_tf_dice: 0.5958
# Epoch 16/20
# 200/200 [==============================] - 184s 920ms/step - loss: 0.2074 - acc: 0.9175 - tf_jaccard: 0.5913 - tf_dice: 0.7220 - val_loss: 0.3260 - val_acc: 0.8600 - val_tf_jaccard: 0.4703 - val_tf_dice: 0.6030
# Epoch 17/20
# 200/200 [==============================] - 184s 921ms/step - loss: 0.1952 - acc: 0.9228 - tf_jaccard: 0.6018 - tf_dice: 0.7286 - val_loss: 0.3643 - val_acc: 0.8574 - val_tf_jaccard: 0.3934 - val_tf_dice: 0.5266
# Epoch 18/20
# 200/200 [==============================] - 185s 924ms/step - loss: 0.1762 - acc: 0.9305 - tf_jaccard: 0.6316 - tf_dice: 0.7515 - val_loss: 0.3519 - val_acc: 0.8683 - val_tf_jaccard: 0.4322 - val_tf_dice: 0.5649
# Epoch 19/20
# 200/200 [==============================] - 182s 911ms/step - loss: 0.1687 - acc: 0.9330 - tf_jaccard: 0.6423 - tf_dice: 0.7614 - val_loss: 0.3662 - val_acc: 0.8730 - val_tf_jaccard: 0.4575 - val_tf_dice: 0.5879
# Epoch 20/20
# 200/200 [==============================] - 182s 910ms/step - loss: 0.1508 - acc: 0.9403 - tf_jaccard: 0.6740 - tf_dice: 0.7855 - val_loss: 0.3836 - val_acc: 0.8732 - val_tf_jaccard: 0.4534 - val_tf_dice: 0.5840
# CPU times: user 32min 47s, sys: 5min 44s, total: 38min 31s
# Wall time: 1h 1min 22s

# %%
print(dir(model.history))
#print(model.history.history)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'epoch', 'history', 'model', 'on_batch_begin', 'on_batch_end', 'on_epoch_begin', 'on_epoch_end', 'on_train_begin', 'on_train_end', 'params', 'set_model', 'set_params', 'validation_data']

# %%
write_json(model.history.history, LOGS_FILENAME)
logs = read_json(LOGS_FILENAME)

# %% [markdown]
# ### Some plots
# __Remember:__
# 1. we use patches (not initial images) for the training part;
# 2. accuracy is not a good metric for image segmentation evaluation (patches with small objects can have good accuracies with zero prediction for all pixels).

# %%
plot_train_val(logs['loss'], logs['val_loss'],
               fig_title='Loss',
               y_label='binary cross entropy')

plot_train_val(logs['tf_jaccard'], logs['val_tf_jaccard'],
               fig_title=f'IoU (thr={config.PRED_THR})',
               y_label='intersection over union')

plot_train_val(logs['tf_dice'], logs['val_tf_dice'],
               fig_title=f'Dice (thr={config.PRED_THR})',
               y_label='dice similarity coefficient')

plot_train_val(logs['acc'], logs['val_acc'],
               fig_title='Accuracy',
               y_label='accuracy')
