# %% [markdown]
# ## 1. Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import skimage
import warnings

from dataset_utils import load_dataset_split

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %%
ICOSEG_SUBSET_80_PATH = '../datasets/icoseg/subset_80'

# %% [markdown]
# ## 2. Load dataset split

# %%
images, masks, img_names = load_dataset_split(ICOSEG_SUBSET_80_PATH, 'val')
print(img_names)
# Out:
# ['2601177796_b8e280ac8a_0_0.png', '2802725781_52d0e4061a_0_0.png', '2803811473_1ba769690b_0_0.png', '2804639140_5ecc0619d4_0_0.png', '2805945719_a77fcbd727_0_0.png', '2805974355_a9259e6d6c_0_0.png', '2806758250_edb11d156c_0_0.png', '2806808284_a2d421ac60_0_0.png', '2825403992_0aa5bdffc5_0_0.png', '583859889_e0a9bed109_0_0.png']

# %%
print('images')
print(images.shape, images.dtype)
print(images.min(), images.max())

print('\nmasks')
print(masks.shape, masks.dtype)
print(masks.min(), masks.max())
# Out:
# images
# (10, 512, 512, 3) float64
# 0.0 1.0
#
# masks
# (10, 512, 512) float64
# 0.0 1.0

# %%
plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.axis('off')
plt.title('image')
plt.imshow(images[0])
plt.subplot(1, 2, 2)
plt.axis('off')
plt.title('mask')
plt.imshow(masks[0], cmap='gray')
plt.show()
